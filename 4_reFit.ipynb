# %%
from Utils.DataConvert import ConvertData
from Utils.fit import Fit
from Utils.FindReaction import FindReaction
from Utils.Format import Format
from Utils.GetFileDir import GetFileDir
from Utils.GetReactionNum import GetReactionNum
import shutil
import os

reactionnum = GetReactionNum()
print(reactionnum)
filename = GetFileDir(reactionnum,'forwardtxt')
print("fit reaction ",filename)
A,n,EAR = Fit(filename, reactionnum)
lines=[]
with open(filename,'r') as f:
    lines=f.readlines()
    for index,i in enumerate(lines):
        if('fit' in i):
            lines[index] = Format('fit','fit',300,2500,A,n,EAR,k0=0)

with open(filename,'w') as f:
    for data in lines:
        f.write(data)
    f.flush()
# Out:
# 254
# fit reaction  Data\254_CH3+CH3(+M)_C2H6(+M)\254_CH3+CH3(+M)_C2H6(+M).txt
# --------------interval is : 100
# --------------interval is : 100
# --------------interval is : 50
# --------------interval is : 25
# --------------interval is : 50
# --------------interval is : 50
# --------------interval is : 100
# --------------interval is : 100
# [ 1.67219117e+25 -2.00000000e+00 -1.41337258e+03]
# sum_error**2 8.175734613855656
# popt: [ 1.67219117e+25 -2.00000000e+00 -1.41337258e+03]
# 系数A: 1.672191168701947e+25
# 系数n: -1.9999999999818219
# 系数EA: -1413.3725821622377
# 系数协方差: [[ 1.62364937e-43 -7.58894382e-24 -3.30559723e-20]
#  [-7.58894382e-24  5.00544705e-04  1.54503774e+00]
#  [-3.30559723e-20  1.54503774e+00  6.72988469e+03]]
# 参数标准差: [4.02945328e-22 2.23728564e-02 8.20358744e+01]
# RSE: 0.9126745747702983
# RSE2: 0.9126745747702983
# std: 0.31197784184134825
# 系数yvals: [22.31510979 21.55371573 21.05298574 20.69001661 20.40997544 20.18438084
#  19.99682303 19.83710584 19.69851866 19.57644003 19.46756839 19.36947265
#  19.28031668 19.19868341 19.12345862 19.05375198 18.98884184 18.92813589
#  18.87114253 18.81744962 18.76670848 18.71862174 18.67293387]
# c:\Users\renxinrui\Documents\Wmp\rxr\overall\Utils\fit.py:129: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   rangeGap = np.array(rangeGap)
